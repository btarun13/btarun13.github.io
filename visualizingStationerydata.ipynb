# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df1 = pd.read_csv('/home/tarun/Documents/CourseFiles/ImportingData_Datasets/mbb.csv',index_col='Month')
#df1.head(100)

a = df1['Mozart'].rolling(20).mean()
b = df1['Mozart'].rolling(5).mean()
y = a.fillna(method = 'bfill')
#x = c.plot()
y.plot()
#ax = b.plot()
#y.head(100)
#y.head(100)
c= y.diff(periods=1)
c.plot()     
#c.head(100)
#ax.plot(label = 'rolling mean')
#ax.set_xlabel("time")
#ax.set_ylabel("price")
#ax.legend()
#df1['Mozart'].plot()
